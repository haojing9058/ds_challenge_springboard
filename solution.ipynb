# %%
import pandas as pd
import numpy as np
% matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.dates as dates

# %%
logs = pd.read_json('logins.json')
logs.head()
# Out:
#            login_time
# 0 1970-01-01 20:13:18
# 1 1970-01-01 20:16:10
# 2 1970-01-01 20:16:37
# 3 1970-01-01 20:16:36
# 4 1970-01-01 20:26:21

# %%
logs.describe()
# Out:
#                  login_time
# count                 93142
# unique                92265
# top     1970-02-12 11:16:53
# freq                      3
# first   1970-01-01 20:12:16
# last    1970-04-13 18:57:38

# %%
#check if missing data
logs['login_time'].isnull().sum()
# Out:
# 0

# %%
logs.dtypes
# Out:
# login_time    datetime64[ns]
# dtype: object

# %%
#insert a counter variable
logs['counter'] =1
logs.head()
# Out:
#            login_time  counter
# 0 1970-01-01 20:13:18        1
# 1 1970-01-01 20:16:10        1
# 2 1970-01-01 20:16:37        1
# 3 1970-01-01 20:16:36        1
# 4 1970-01-01 20:26:21        1

# %%
by_day = logs.resample('D', on='login_time').sum()
by_day['weekday'] = by_day.index.weekday
ax = plt.figure(figsize=(16,6)).add_subplot(1,1,1)
by_day['counter'].plot(kind='bar')
ax.set_xticklabels(by_day['weekday'], rotation=0)

# ax.set_xticklabels(by_day['weekday'], minor=True)
# ax.set_xticklabels(by_day['weekday'], minor=True)
plt.show()

# %%
fig = plt.figure(figsize=(16,6))
ax = fig.add_subplot(1,1,1)
ax.plot(by_hour['counter'])
